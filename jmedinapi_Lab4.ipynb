# %% [markdown]
# # SymPyLab
#
# SymPy’s documentation
# - https://docs.sympy.org/latest/index.html

# %% [markdown]
# ## SymPy’s polynomials
# - https://docs.sympy.org/latest/modules/polys/basics.html#polynomials
#
# $$ P_n(x) =  a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0$$
#
# $$P_n(x) = 0 $$
#
# $$a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0 = 0$$
#
# $$(x-r_1) Q_{n-1}(x) = P_n(x)$$
# $$(x-r_1) (x - r_2) Q_{n-2}(x) = P_n(x)$$
# $$ \vdots $$

# %% [markdown]
# # Number of operations to compute a polynomial
# ## Extended
# $$ a_5 x^5 + a_4 x^4 + a_3 x^3 + a_2 x^2 + a_1 x + a_0 = a_5*x*x*x*x*x + a_4*x*x*x*x  + a_3*x*x*x + a_2*x*x + a_1*x + a_0$$
#
# $$ 5+4+3+2+1 = \frac{5*6}{2} (*) + 5 (+)  =20 \text{ ops} $$
#
# $$ a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} + \cdots + a_2 x^2 + a_1 x + a_0$$
#
# $$ \frac{n(n+1)}{2} (*) + n (+)  =\frac{n^2}{2} + \frac{3}{2} n\text{ ops} $$

# %% [markdown]
# ## Monomials product
#
# $$(x-r_1)(x-r_2)(x-r_3)(x-r_4)(x-r_5)$$
#
#
# $$ 5 (-) + 4 (*) = 9  \text{ ops} $$
#
# $$(x-r_1)(x-r_2)(x-r_3)\cdots (x-r_{n-1})(x-r_n)$$
#
# $$ n-1 (*) + n (-)  =  2n-1 \text{ ops} $$

# %% [markdown]
# ## Nexted
# $$  ((((a_5 x+ a_4 )x  + a_3) x + a_2)x +a_1)x + a_0 $$
#
# $$ 5 (*) + 5 (+)  = 10 \text{ ops} $$
#
#
# $$ ((((a_n x+ a_{n-1} )x  + a_{n-1}) x + \cdots a_2)x +a_1)x + a_0 $$
#
# $$ n (*) + n (+)  = 2n \text{ ops} $$

# %% [markdown]
# ## **My Own Example**
# Juan Medina Id Code = 48. \\
# 48 mod 10 = 8.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# My polynomial divided by a root
# ![image.png](attachment:image.png)

# %% [markdown]
# My polynomial divided by a NON root
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Sympy divide my polynomial by all 10 roots

# %%
from sympy import Symbol, div

x = Symbol('x')

p = x**10 - 6733*x**9 + 9236849*x**8 - 2606391511*x**7 - 2416070457130*x**6 + 1521980135707652*x**5 - 135002809001881928*x**4 - 39679943449834761120*x**3 + 146037600624586694400*x**2 + 7401496072000354560000*x - 47738506038769059840000

factores = [-548, -118, -15,8,10, 503, 555, 632, 696, 5010]

for i in range(1, 11):
    divisor = x - factores[i - 1]
    p, r = div(p, divisor)

    print(f"Raíz {i}ª tiene como resultado: {divisor} con residuo {r}")
# Out:
# Raíz 1ª tiene como resultado: x + 548 con residuo 0
# Raíz 2ª tiene como resultado: x + 118 con residuo 0
# Raíz 3ª tiene como resultado: x + 15 con residuo 0
# Raíz 4ª tiene como resultado: x - 8 con residuo 0
# Raíz 5ª tiene como resultado: x - 10 con residuo 0
# Raíz 6ª tiene como resultado: x - 503 con residuo 0
# Raíz 7ª tiene como resultado: x - 555 con residuo 0
# Raíz 8ª tiene como resultado: x - 632 con residuo 0
# Raíz 9ª tiene como resultado: x - 696 con residuo 0
# Raíz 10ª tiene como resultado: x - 5010 con residuo 0

# %% [markdown]
# Sympy divides my polynomial by a NO root

# %%
p = x**10 - 6733*x**9 + 9236849*x**8 - 2606391511*x**7 - 2416070457130*x**6 + 1521980135707652*x**5 - 135002809001881928*x**4 - 39679943449834761120*x**3 + 146037600624586694400*x**2 + 7401496072000354560000*x - 47738506038769059840000

p, r = div(p,  x-55)
print("No es Raiz x-55")
print("Resultado: ", p)
print("Residuo: ", r)
# Out:
# No es Raiz x-55
# Resultado:  x**9 - 6678*x**8 + 8869559*x**7 - 2118565766*x**6 - 2532591574260*x**5 + 1382687599123352*x**4 - 58954991050097568*x**3 - 42922467957590127360*x**2 - 2214698137042870310400*x - 114406901465357512512000
# Residuo:  -6340118086633432248000000

# %% [markdown]
# ## SymPy’s polynomial simple univariate polynomial factorization
# - https://docs.sympy.org/latest/modules/polys/wester.html#simple-univariate-polynomial-factorization
# - factor( x^10 - 10x^9 + 45x^8 - 120x^7 + 210x^6 - 252x^5 + 210x^4 - 120x^3 + 45x^2 - 10x + 1
# )

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**10 - 10*x**9 + 45*x**8 - 120*x**7 + 210*x**6 - 252*x**5 + 210*x**4 - 120*x**3 + 45*x**2 - 10*x + 1)
# Out:
# (x - 1)**10

# %% [markdown]
# ## SymPy’s solvers
# - https://docs.sympy.org/latest/tutorial/solvers.html
# -6\*x\*\*10 - 12383\*x\*\*9 + 7171471\*x\*\*8 - 591002230\*x\*\*7 - 172290611876\*x\*\*6 - 8293633126927\*x\*\*5 - 134026025424341\*x\*\*4 - 222242274748700\*x\*\*3 + 10998048706342500\*x\*\*2 + 70746676434000000\*x + 97613189100000000

# %% [markdown]
# ## Se introdujo la factorizacion por que expandido es muy grande y no se ve bien
#
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq
x = Symbol('x')
solveset(Eq(6*x**10 - 12383*x**9 + 7171471*x**8 - 591002230*x**7 - 172290611876*x**6 - 8293633126927*x**5 - 134026025424341*x**4 - 222242274748700*x**3 + 10998048706342500*x**2 + 70746676434000000*x + 97613189100000000, 0), x)
# Out:
# {-69, -25, -25/2, -6, -2, 9, 952/3, 925, 952}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq, sqrt, pi, E
x = Symbol('x')
solveset(Eq(89*x**2 - (pi*x)**2 + sqrt(98) + 8 - pi, 0), x)
# Out:
# {-sqrt(-7*sqrt(2) - 8 + pi)/sqrt(89 - pi**2), sqrt(-7*sqrt(2) - 8 + pi)/sqrt(89 - pi**2)}

# %% [markdown]
# *   Reference docs for the Poly Domains https://docs.sympy.org/dev/modules/polys/domainsref.html
#
# *   Introducing the Domains of the poly module https://docs.sympy.org/dev/modules/polys/domainsintro.html
#
# *   Internals of the Polynomial Manipulation Module https://docs.sympy.org/latest/modules/polys/internals.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**5 + 22 *x **4 + 102 *x **3 - 648 *x **2 - 5103 *x - 4374,domain='GF(3)')
# Out:
# x**4*(x + 1)

# %% [markdown]
# ## SymPy’s Symbolic and Numercical Complex Evaluations
# - https://docs.sympy.org/latest/modules/evalf.html](https://)
# - x = x1 + I*x2,y = y1 + I*y2, z = z1 + I*z2, x * y * z

# %% [markdown]
# <img src="https://raw.githubusercontent.com/gjhernandezp/NM/main/SymPyLab/sympylabwolfram7.jpg" />

# %%
from sympy import symbols, I, N, pi, expand
x1, x2, y1, y2, z1, z2 = symbols("x1 x2 y1 y2 z1 z2", real=True)
x = x1 + I*x2
y = y1 + I*y2
z = z1 + I*z2

print(x*y*z)
print(expand(x*y*z))
print(expand((x*y)*z))
print(expand(x*(y*z)))
w=1/(pi + I)
print('w=',w)
w=N(w)
print('w=',w)
# Out:
# (x1 + I*x2)*(y1 + I*y2)*(z1 + I*z2)
# x1*y1*z1 + I*x1*y1*z2 + I*x1*y2*z1 - x1*y2*z2 + I*x2*y1*z1 - x2*y1*z2 - x2*y2*z1 - I*x2*y2*z2
# x1*y1*z1 + I*x1*y1*z2 + I*x1*y2*z1 - x1*y2*z2 + I*x2*y1*z1 - x2*y1*z2 - x2*y2*z1 - I*x2*y2*z2
# x1*y1*z1 + I*x1*y1*z2 + I*x1*y2*z1 - x1*y2*z2 + I*x2*y1*z1 - x2*y1*z2 - x2*y2*z1 - I*x2*y2*z2
# w= 1/(pi + I)
# w= 0.289025482222236 - 0.0919996683503752*I

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sympy import symbols, I, N, pi, expand
y1, y2, z1, z2, x1, x2 = symbols("x1 x2 y1 y2 z1 z2", real=True)

x = 89*x1 + I*x2
y = 99*y1 + I*y2
z = 605*z1 + I*z2

print(x*y)
print(expand(x*y*z))
print(expand((x*y)*z))
print(expand(x*(y*z)))
u=1/(2*pi + I)
print('u=',u)
u=N(u)
print('u=',u)
# Out:
# (99*x1 + I*x2)*(89*z1 + I*z2)
# 5330655*x1*y1*z1 + 59895*I*x1*y1*z2 + 8811*I*x1*y2*z1 - 99*x1*y2*z2 + 53845*I*x2*y1*z1 - 605*x2*y1*z2 - 89*x2*y2*z1 - I*x2*y2*z2
# 5330655*x1*y1*z1 + 59895*I*x1*y1*z2 + 8811*I*x1*y2*z1 - 99*x1*y2*z2 + 53845*I*x2*y1*z1 - 605*x2*y1*z2 - 89*x2*y2*z1 - I*x2*y2*z2
# 5330655*x1*y1*z1 + 59895*I*x1*y1*z2 + 8811*I*x1*y2*z1 - 99*x1*y2*z2 + 53845*I*x2*y1*z1 - 605*x2*y1*z2 - 89*x2*y2*z1 - I*x2*y2*z2
# u= 1/(2*pi + I)
# u= 0.155223096134648 - 0.0247045230318576*I

# %% [markdown]
# ## Wolfram alpha answers quastion in natural languaje
# - What is the average salary for computer scientific?
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Try the same question asked in Wolfram Alpha in ChatGPT**
#
# https://chat.openai.com/auth/login
#
# and post the answer screenshoot.

# %% [markdown]
# # New Section
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## SymPy’s integrate
#
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, sin,cos
x = Symbol('x')
integrate(x**5 * cos(x), x)
# Out:
# x**5*sin(x) + 5*x**4*cos(x) - 20*x**3*sin(x) - 60*x**2*cos(x) + 120*x*sin(x) + 120*cos(x)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, sin,cos
x = Symbol('x')
integrate(x**5* cos(x),x)
# Out:
# x**5*sin(x) + 5*x**4*cos(x) - 20*x**3*sin(x) - 60*x**2*cos(x) + 120*x*sin(x) + 120*cos(x)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, cos
x = Symbol('x')
integrate(x**3 * cos(x)**2, (x,3,4))
# Out:
# -105*cos(3)**2/8 - 27*sin(3)**2/4 - 45*sin(3)*cos(3)/4 + 29*sin(4)*cos(4) + 26*sin(4)**2 + 301*cos(4)**2/8

# %%
from sympy import Symbol, integrate, sin, N,cos
x = Symbol('x')
N(integrate(x**3 * cos(x)**2, (x,3,4)))
# Out:
# 33.8861450181974
